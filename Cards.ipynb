# %% [markdown]
# <h1>Customer.csv</h1>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:/Users/Parth/Power_BI/Credit Card Project/customer.csv")

# %%
df.columns
# Out:
# Index(['Client_Num', 'Customer_Age', 'Gender', 'Dependent_Count',
#        'Education_Level', 'Marital_Status', 'state_cd', 'Zipcode', 'Car_Owner',
#        'House_Owner', 'Personal_loan', 'contact', 'Customer_Job', 'Income',
#        'Cust_Satisfaction_Score'],
#       dtype='object')

# %%
df.head()
# Out:
#    Client_Num  Customer_Age Gender  Dependent_Count Education_Level  \
# 0   708082083            24      F                1      Uneducated
# 1   708083283            62      F                0         Unknown
# 2   708084558            32      F                1         Unknown
# 3   708085458            38      M                2      Uneducated
# 4   708086958            48      M                4        Graduate
#
#   Marital_Status state_cd  Zipcode Car_Owner House_Owner Personal_loan  \
# 0         Single       FL    91750        no         yes            no
# 1        Married       NJ    91750        no          no            no
# 2        Married       NJ    91750       yes          no            no
# 3         Single       NY    91750        no          no            no
# 4         Single       TX    91750       yes         yes            no
#
#     contact   Customer_Job  Income  Cust_Satisfaction_Score
# 0   unknown    Businessman  202326                        3
# ...

# %%
df.tail()
# Out:
#        Client_Num  Customer_Age Gender  Dependent_Count Education_Level  \
# 49994   827930645            57      M                0        Graduate
# 49995   827930646            70      M                5        Graduate
# 49996   827930647            64      M                5     High School
# 49997   827930648            31      M                0   Post-Graduate
# 49998   827930649            29      F                0        Graduate
#
#       Marital_Status state_cd  Zipcode Car_Owner House_Owner Personal_loan  \
# 49994         Single       CA    91750        no          no            no
# 49995        Married       TX    91750       yes          no           yes
# 49996        Married       FL    91750        no          no            no
# 49997         Single       TX    91750        no         yes            no
# 49998         Single       TX    91750        no         yes            no
#
#         contact   Customer_Job  Income  Cust_Satisfaction_Score
# ...

# %%
df2.shape
# Out:
# (49999, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49999 entries, 0 to 49998
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Client_Num               49999 non-null  int64
#  1   Customer_Age             49999 non-null  int64
#  2   Gender                   49999 non-null  object
#  3   Dependent_Count          49999 non-null  int64
#  4   Education_Level          49999 non-null  object
#  5   Marital_Status           49999 non-null  object
#  6   state_cd                 49999 non-null  object
#  7   Zipcode                  49999 non-null  int64
#  8   Car_Owner                49999 non-null  object
#  9   House_Owner              49999 non-null  object
#  10  Personal_loan            49999 non-null  object
#  11  contact                  49999 non-null  object
#  12  Customer_Job             49999 non-null  object
#  13  Income                   49999 non-null  int64
# ...

# %%
df.describe(include="all")
# Out:
#           Client_Num  Customer_Age Gender  Dependent_Count Education_Level  \
# count   4.999900e+04  49999.000000  49999     49999.000000           49999
# unique           NaN           NaN      2              NaN               6
# top              NaN           NaN      F              NaN        Graduate
# freq             NaN           NaN  29092              NaN           20289
# mean    8.099383e+08     46.844197    NaN         2.467509             NaN
# std     3.933931e+07     14.116629    NaN         1.638306             NaN
# min     7.080821e+08     21.000000    NaN         0.000000             NaN
# 25%     8.278932e+08     36.000000    NaN         1.000000             NaN
# 50%     8.279056e+08     47.000000    NaN         2.000000             NaN
# 75%     8.279181e+08     58.000000    NaN         4.000000             NaN
# max     8.279306e+08     73.000000    NaN         5.000000             NaN
#
# ...

# %%
df.isnull().sum()
df.isna().sum()
# Out:
# Client_Num                 0
# Customer_Age               0
# Gender                     0
# Dependent_Count            0
# Education_Level            0
# Marital_Status             0
# state_cd                   0
# Zipcode                    0
# Car_Owner                  0
# House_Owner                0
# Personal_loan              0
# contact                    0
# Customer_Job               0
# Income                     0
# Cust_Satisfaction_Score    0
# dtype: int64

# %%
df['Client_Num'].is_unique
# Out:
# True

# %%
df['contact'] = df['contact'].replace('unknown', 'Not Available')

# %%
from sqlalchemy import create_engine, text

engine = create_engine("mysql+pymysql://root:rootuser@localhost:3306/cards")

with engine.connect() as conn:
 result = conn.execute(text("SELECT DATABASE();"))
 print("Connected to:", result.fetchone())
# Out:
# Connected to: ('cards',)

# %%
table_name = "customer"
df.to_sql(table_name, engine, if_exists="replace", index=False)
# Out:
# 49999

# %%
pd.read_sql("SELECT * FROM customer LIMIT 5;", engine)
# Out:
#    Client_Num  Customer_Age Gender  Dependent_Count Education_Level  \
# 0   708082083            24      F                1      Uneducated
# 1   708083283            62      F                0         Unknown
# 2   708084558            32      F                1         Unknown
# 3   708085458            38      M                2      Uneducated
# 4   708086958            48      M                4        Graduate
#
#   Marital_Status state_cd  Zipcode Car_Owner House_Owner Personal_loan  \
# 0         Single       FL    91750        no         yes            no
# 1        Married       NJ    91750        no          no            no
# 2        Married       NJ    91750       yes          no            no
# 3         Single       NY    91750        no          no            no
# 4         Single       TX    91750       yes         yes            no
#
#          contact   Customer_Job  Income  Cust_Satisfaction_Score
# ...

# %% [markdown]
# <h1>credit_card.csv</h1>

# %%
df2 = pd.read_csv("C:/Users/Parth/Power_BI/Credit Card Project/credit_card.csv")

# %%
df2.head()
# Out:
#    Client_Num Card_Category  Annual_Fees  Activation_30_Days  \
# 0   708082083          Blue          200                   0
# 1   708083283          Blue          445                   1
# 2   708084558          Blue          140                   0
# 3   708085458          Blue          250                   1
# 4   708086958          Blue          320                   1
#
#    Customer_Acq_Cost Week_Start_Date Week_Num Qtr  current_year  Credit_Limit  \
# 0                 87      01-01-2023   Week-1  Q1          2023        3544.0
# 1                108      01-01-2023   Week-1  Q1          2023        3421.0
# 2                106      01-01-2023   Week-1  Q1          2023        8258.0
# 3                150      01-01-2023   Week-1  Q1          2023        1438.3
# 4                106      01-01-2023   Week-1  Q1          2023        3128.0
#
#    Total_Revolving_Bal  Total_Trans_Amt  Total_Trans_Vol  \
# 0                 1661            15149              111
# ...

# %%
df2.tail()
# Out:
#        Client_Num Card_Category  Annual_Fees  Activation_30_Days  \
# 49994   827930645          Blue          200                   1
# 49995   827930646          Blue          475                   0
# 49996   827930647          Blue          125                   0
# 49997   827930648          Blue          245                   0
# 49998   827930649          Gold          495                   0
#
#        Customer_Acq_Cost Week_Start_Date Week_Num Qtr  current_year  \
# 49994                 62      29-10-2023  Week-43  Q4          2023
# 49995                153      16-07-2023  Week-28  Q3          2023
# 49996                143      20-08-2023  Week-33  Q3          2023
# 49997                101      01-10-2023  Week-39  Q4          2023
# 49998                 90      19-11-2023  Week-46  Q4          2023
#
#        Credit_Limit  Total_Revolving_Bal  Total_Trans_Amt  Total_Trans_Vol  \
# 49994       10345.4                 1956            17260               41
# ...

# %%
df2.shape
# Out:
# (49999, 18)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49999 entries, 0 to 49998
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Client_Num             49999 non-null  int64
#  1   Card_Category          49999 non-null  object
#  2   Annual_Fees            49999 non-null  int64
#  3   Activation_30_Days     49999 non-null  int64
#  4   Customer_Acq_Cost      49999 non-null  int64
#  5   Week_Start_Date        49999 non-null  object
#  6   Week_Num               49999 non-null  object
#  7   Qtr                    49999 non-null  object
#  8   current_year           49999 non-null  int64
#  9   Credit_Limit           49999 non-null  float64
#  10  Total_Revolving_Bal    49999 non-null  int64
#  11  Total_Trans_Amt        49999 non-null  int64
#  12  Total_Trans_Vol        49999 non-null  int64
#  13  Avg_Utilization_Ratio  49999 non-null  float64
# ...

# %%
df2.describe(include="all")
# Out:
#           Client_Num Card_Category   Annual_Fees  Activation_30_Days  \
# count   4.999900e+04         49999  49999.000000        49999.000000
# unique           NaN             4           NaN                 NaN
# top              NaN          Blue           NaN                 NaN
# freq             NaN         45597           NaN                 NaN
# mean    8.099383e+08           NaN    291.156123            0.512650
# std     3.933931e+07           NaN    118.131000            0.499845
# min     7.080821e+08           NaN     95.000000            0.000000
# 25%     8.278932e+08           NaN    195.000000            0.000000
# 50%     8.279056e+08           NaN    290.000000            1.000000
# 75%     8.279181e+08           NaN    395.000000            1.000000
# max     8.279306e+08           NaN    500.000000            1.000000
#
#         Customer_Acq_Cost Week_Start_Date Week_Num    Qtr  current_year  \
# ...

# %%
df2.isnull().sum()
df2.isna().sum()
# Out:
# Client_Num               0
# Card_Category            0
# Annual_Fees              0
# Activation_30_Days       0
# Customer_Acq_Cost        0
# Week_Start_Date          0
# Week_Num                 0
# Qtr                      0
# current_year             0
# Credit_Limit             0
# Total_Revolving_Bal      0
# Total_Trans_Amt          0
# Total_Trans_Vol          0
# Avg_Utilization_Ratio    0
# Use Chip                 0
# Exp Type                 0
# Interest_Earned          0
# Delinquent_Acc           0
# dtype: int64

# %%
df2['Client_Num'].is_unique
# Out:
# True

# %%
table_name = "credit_card"
df2.to_sql(table_name, engine, if_exists="replace", index=False)
# Out:
# 49999

# %%
pd.read_sql("SELECT * FROM credit_card LIMIT 5;", engine)
# Out:
#    Client_Num Card_Category  Annual_Fees  Activation_30_Days  \
# 0   708082083          Blue          200                   0
# 1   708083283          Blue          445                   1
# 2   708084558          Blue          140                   0
# 3   708085458          Blue          250                   1
# 4   708086958          Blue          320                   1
#
#    Customer_Acq_Cost Week_Start_Date Week_Num Qtr  current_year  Credit_Limit  \
# 0                 87      01-01-2023   Week-1  Q1          2023        3544.0
# 1                108      01-01-2023   Week-1  Q1          2023        3421.0
# 2                106      01-01-2023   Week-1  Q1          2023        8258.0
# 3                150      01-01-2023   Week-1  Q1          2023        1438.3
# 4                106      01-01-2023   Week-1  Q1          2023        3128.0
#
#    Total_Revolving_Bal  Total_Trans_Amt  Total_Trans_Vol  \
# 0                 1661            15149              111
# ...

# %% [markdown]
# <h1>both files checking</h1>

# %%
common_clients = df[df['Client_Num'].isin(df2['Client_Num'])]

common_clients
# Out:
#        Client_Num  Customer_Age Gender  Dependent_Count Education_Level  \
# 0       708082083            24      F                1      Uneducated
# 1       708083283            62      F                0         Unknown
# 2       708084558            32      F                1         Unknown
# 3       708085458            38      M                2      Uneducated
# 4       708086958            48      M                4        Graduate
# ...           ...           ...    ...              ...             ...
# 49994   827930645            57      M                0        Graduate
# 49995   827930646            70      M                5        Graduate
# 49996   827930647            64      M                5     High School
# 49997   827930648            31      M                0   Post-Graduate
# 49998   827930649            29      F                0        Graduate
#
#       Marital_Status state_cd  Zipcode Car_Owner House_Owner Personal_loan  \
# ...

# %%
df['Client_Num'].isin(df2['Client_Num']).any()
# Out:
# np.True_

# %%
df['Client_Num'].isin(df2['Client_Num']).sum()
# Out:
# np.int64(49999)

# %%
common = set(df['Client_Num']).intersection(set(df2['Client_Num']))
print(len(common))
# Out:
# 49999
